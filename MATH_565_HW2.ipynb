# %% [markdown]
# <a href="https://colab.research.google.com/github/ferriitoo/ChicagoIIT/blob/main/MATH_565_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math



exercise_number = 5 #choose the exercise number, 4 or 5
if (exercise_number == 4) :
  print("The exercise number 4 will be solved")

  #Parameter declaration

elif (exercise_number == 5):
  print("The exercise number 5 will be solved")
  
  #Parameter declaration
  alpha = 2
  beta = 2
  n_variables = 1000
  
  def ganma(n):
    value = 1
    for i in range(1,n):
      value = value * i
    return value  

  def B_function(alpha, beta):
    value = ganma(alpha) * ganma(beta) / ganma(alpha+beta)
    return value

  def density(x):
    if (x >= 0.0 and x <= 1.0 ): #check if x domain restrictions are respected
      #print("X domain constraints have been respected")
      calculus = math.pow(alpha, alpha-1) * math.pow(1-x, beta-1) / B_function(alpha, beta)
    else:
      print("X domain constraints have not been respected")
    return calculus

  random_array = []
  random_array.append(0)

  for i in range(n_variables): 
    random_array.append(density(np.random.rand()))
    

  print(random_array)
# Out:
# The exercise number 5 will be solved
# [0, 6.685063472060517, 4.213488455620372, 9.339070675815966, 9.231567843861564, 3.884895927431747, 7.31494579705445, 7.67155673498192, 1.827351192132812, 3.4843589591972504, 0.3172379174497637, 2.1774290980744206, 4.821889416330098, 11.132229265678154, 1.3046139361107056, 10.870565579396938, 10.274146395805948, 2.750762994225652, 0.262715285534703, 7.960706733285613, 6.402603079692205, 5.763248569355603, 7.789683899443918, 3.2170186844125706, 10.514640316096072, 3.481037847144793, 9.09441467306643, 2.582669102195705, 9.48594424974317, 5.143900458112494, 10.556261399923514, 0.54425514362197, 5.573033981757086, 9.979465182403565, 5.161528413305547, 7.259939719019053, 0.4466144323770962, 11.178142346155152, 10.522379318677068, 3.5699353574615897, 0.21680232417750256, 8.373038926656744, 11.087604166968461, 3.9094185357369944, 9.445197606884753, 2.953696351991204, 2.171334095410764, 2.550708134794925, 7.378941248902411, 0.29260782862919, 8.835904709588787, 10.363266857465751, 11.013915000014405, 9.728176497706421, 3.097695767990511, 10.473863155556204, 4.359731358292748, 11.769716299817722, 6.901893524233947, 6.430093717947213, 0.9189992419961777, 6.493035227909169, 5.239784068972635, 6.0973977140306745, 7.052912466835365, 11.796374595530631, 0.185390632834034, 1.656089373599709, 6.859118655070773, 9.77000107016841, 2.39499197660021, 11.280274550467412, 3.5077511912784196, 9.882493550567862, 4.026377260219924, 11.562505506459967, 7.131173745294945, 0.44662698995160843, 7.339589