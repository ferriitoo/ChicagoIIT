# %% [markdown]
# <a href="https://colab.research.google.com/github/ferriitoo/ChicagoIIT/blob/main/MATH_565_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math



exercise_number = 5 #choose the exercise number, 4 or 5
if (exercise_number == 4) :
  print("The exercise number 4 will be solved")

  #Parameter declaration

elif (exercise_number == 5):
  print("The exercise number 5 will be solved")
  
  #Parameter declaration
  alpha = 2
  beta = 2
  n_variables = 1000
  
  def ganma(n):
    value = 1
    for i in range(1,n):
      value = value * i
    return value  

  def B_function(alpha, beta):
    value = ganma(alpha) * ganma(beta) / ganma(alpha+beta)
    return value

  def density(x):
    if (x >= 0.0 and x <= 1.0 ): #check if x domain restrictions are respected
      #print("X domain constraints have been respected")
      calculus = math.pow(alpha, alpha-1) * math.pow(1-x, beta-1) / B_function(alpha, beta)
    else:
      print("X domain constraints have not been respected")
    return calculus

  random_array = []
  random_array.append(0)

  for i in range(n_variables): 
    random_array.append(round(density(np.random.rand()),2))
    

  print(random_array)
# Out:
# The exercise number 5 will be solved
# [0, 1.49, 1.43, 4.75, 1.05, 3.9, 6.47, 8.63, 3.61, 2.39, 0.99, 11.66, 8.81, 5.04, 2.8, 2.76, 9.25, 0.95, 0.28, 11.12, 6.8, 10.39, 11.55, 7.02, 9.78, 8.43, 2.51, 0.77, 7.06, 3.83, 1.77, 7.82, 6.28, 1.52, 2.23, 5.25, 6.75, 7.53, 3.67, 7.81, 9.89, 1.8, 8.24, 11.93, 9.2, 4.42, 6.27, 3.85, 9.93, 11.42, 8.46, 4.99, 10.22, 5.26, 7.93, 9.96, 5.73, 3.66, 5.44, 11.78, 5.69, 10.56, 8.81, 8.52, 9.73, 0.05, 3.23, 9.12, 1.79, 7.22, 5.46, 4.22, 11.85, 5.86, 2.26, 0.76, 6.2, 8.09, 3.25, 2.1, 9.57, 5.14, 4.22, 1.99, 6.81, 9.32, 7.57, 8.56, 5.46, 2.62, 3.63, 8.35, 6.34, 5.77, 8.95, 8.99, 11.54, 1.33, 3.71, 5.88, 0.37, 3.64, 7.14, 3.09, 11.5, 5.91, 3.75, 0.18, 0.47, 1.43, 3.63, 4.25, 2.57, 9.79, 3.28, 0.66, 8.72, 3.9, 3.27, 7.15, 4.0, 1.11, 10.08, 11.65, 11.0, 2.57, 0.8, 8.69, 11.28, 9.8, 7.89, 5.09, 1.89, 7.23, 9.64, 5.31, 6.49, 10.7, 1.0, 4.44, 9.59, 9.67, 1.88, 3.21, 9.43, 10.75, 10.92, 1.09, 9.06, 4.76, 9.86, 1.45, 5.2, 10.57, 4.08, 10.36, 9.06, 10.24, 0.42, 7.19, 7.31, 7.41, 11.03, 3.24, 2.8, 5.25, 8.74, 1.92, 4.32, 4.39, 4.57, 5.48, 5.49, 10.78, 10.81, 5.35, 8.0, 10.65, 3.71, 2.98, 7.3, 4.79, 10.08, 3.08, 4.53, 1.43, 10.8, 9.69, 4.49, 7.53, 8.87, 3.76, 1.75, 3.9, 9.47, 8.92, 11.21, 1.0, 4.43, 0.37, 7.45, 8.72, 2.2, 0.03, 5.06, 11.89, 11.31, 5.38, 0.08, 3.58, 1.24, 10.88, 6.56, 7.21, 1.85, 6.89, 2.56, 3.42, 2.49, 4.95, 6.29, 1.13, 2.97, 10.94, 5.02, 3.14, 5.63, 1.43, 0.78, 10.31, 7.47, 9.13, 10.96, 9.54, 0.87, 0.58, 5.39, 2.14, 4.27, 5.75, 4.42, 6.11, 3.0, 6.58, 10.17, 0.52, 6.49, 0.61, 6.07, 5.27, 8.54, 9.79, 11.96, 9.0, 8.29, 0.08, 10.49, 1.79, 3.61, 3.28, 2.19, 7.16, 2.46, 2.63, 6.72, 6.45, 3.54, 3.78, 6.16, 8.52, 11.24, 5.11, 4.22, 11.35, 5.51, 1.61, 7.96, 3.29