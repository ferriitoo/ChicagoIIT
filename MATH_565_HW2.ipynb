# %% [markdown]
# <a href="https://colab.research.google.com/github/ferriitoo/ChicagoIIT/blob/main/MATH_565_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import sympy as sy



exercise_number = 5 #choose the exercise number, 3 or 5
if (exercise_number == 3) :
  print("The exercise number 3 will be solved")

  A = [[ 1/2, 1/2 ],[ 1/2, 1 ]]
  A_inv = np.linalg.inv(A)
  det_A = np.linalg.det(A)
  integrate(function(z), z, inf, inf)

  def S_1(z): 
    value = 100*math.exp(-0.0225 + 0.3 * z)
    return value

  def S_2(z): 
    value = 100*math.exp(-0.045 + 0.3 * z)
    return value
  
  @latexify.with_latex
  def function(z):
    max(1/2*(S_1(z) + S_2(z)) - 100) * math.exp( A_inv) / sqrt(4 * (math.pi**2) * det_(A) )
  sync
  #Parameter declaration
  
  def integrate(f, x, a, b ):
    z = sy.Simble("x")
    return sy.integrate(f, (x, a, b))

  


elif (exercise_number == 5):
  print("The exercise number 5 will be solved")
  
  #Parameter declaration
  alpha = 2
  beta = 2
  n_variables = 1000
  
  def ganma(n):
    value = 1
    for i in range(1,n):
      value = value * i
    return value  

  def B_function(alpha, beta):
    value = ganma(alpha) * ganma(beta) / ganma(alpha+beta)
    return value

  def density(x):
    if (x >= 0.0 and x <= 1.0 ): #check if x domain restrictions are respected
      #print("X domain constraints have been respected")
      calculus = math.pow(alpha, alpha-1) * math.pow(1-x, beta-1) / B_function(alpha, beta)
    else:
      print("X domain constraints have not been respected")
    return calculus

  random_array = []
  random_array.append(0)

  for i in range(n_variables): 
    random_array.append(round(density(np.random.rand()),2))
    

  print(random_array)
# Out:
# The exercise number 5 will be solved
# [0, 4.01, 4.89, 2.2, 0.24, 5.99, 8.79, 11.44, 6.64, 2.2, 4.58, 4.5, 10.23, 0.3, 3.57, 7.04, 6.13, 1.97, 11.8, 7.74, 4.09, 11.62, 7.84, 0.37, 4.83, 2.29, 0.58, 5.01, 0.34, 1.49, 1.03, 9.8, 8.14, 6.15, 10.98, 0.29, 11.41, 0.86, 1.26, 1.61, 4.96, 2.57, 5.48, 9.73, 7.63, 0.45, 1.33, 10.67, 11.25, 7.6, 7.24, 7.61, 1.0, 6.18, 11.94, 0.81, 5.16, 7.75, 8.57, 10.8, 5.93, 10.53, 1.19, 4.69, 9.74, 1.41, 2.14, 7.51, 2.45, 3.99, 9.89, 2.99, 9.74, 1.04, 1.92, 1.1, 4.96, 1.44, 8.51, 0.29, 6.16, 4.21, 2.92, 4.98, 8.99, 10.92, 9.97, 7.24, 8.93, 9.9, 10.4, 6.14, 2.59, 5.96, 2.67, 10.02, 8.25, 2.43, 7.27, 0.29, 1.02, 11.88, 1.74, 7.98, 10.48, 8.75, 11.38, 10.92, 8.83, 0.3, 1.79, 3.22, 5